# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/17 03:10:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/17 03:10:45 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
rdd = spark.sparkContext.parallelize(df_random)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rdd = spark.sparkContext.parallelize(df_random)
#
# NameError: name 'df_random' is not defined

# %%
data = [
    (1, "Amit", "IT", 55000),
    (2, "Rahul", "HR", 40000),
    (3, "Neha", "IT", 65000),
    (4, "Priya", "Finance", 70000),
    (5, "Karan", "IT", 50000),
    (6, "Simran", "HR", 45000),
    (7, "Rohit", "Finance", 60000)
]

columns = ["id", "name", "department", "salary"]

df = spark.createDataFrame(data, columns)

df.write.mode("overwrite").csv("output/employee.csv", header=True)
